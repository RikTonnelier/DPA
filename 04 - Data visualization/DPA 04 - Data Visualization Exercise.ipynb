# %% [markdown]
# # Chapter 4: Data Visualization

# %%
# %reset
low_memory=False
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 4.1 Introduction & Problem Setting

# %% [markdown]
# There are a number of options for visualising data. See the figure below by Claus Wilke for a number of examples.
#
# ![](https://bookdown.org/wangminjie/R4DS/images/common-aesthetics.png)
#
# Not al visualisation types are appropriate for each data type. Let's explore this with the titanic dataset!
#
# By now you should be familiar with the different columns and datatypes. Make an interesting plot with the titanic data! Remember that the story is crucial! What are you trying to visualise and how can the aesthetics help you tell that story? Keep the following things under consideration (not all are applicable/neccessary for each plot):
#
# - Position: The position is determined by the plot type, e.g.
#     - plot(x, y)
#     - scatter(x, y)
#     - hist(x)
#     - etc.
# - Shape: You can use **marker** option in matplotlib. Unfortunately can not be an array, so only 1 marker per plot (Can you think of a work around?).
# - Size: You can use the **s** option in matplotlib
# - Colour: you can use the **c** or **color** option. ('color' is prefered for a single colour, 'c' for an array)
# - Line width: You can use the **linewidth** option in matplotlib.
# - Line type: You can use the **linestyle** option in matplotlib.

# %% [markdown]
# ## 4.2 Data Loading & Exploration

# %% [markdown]
# *Load in your titanic data. You can either use the dataset you have cleaned yourself last week, or use mine from Github.*

# %% [markdown]
# ## 4.3 Data visualization

# %% [markdown]
# *Show me your visualizations! Make sure you don't just show a plot but tell an actual story! Try to make at least 3 vizualizations.*
