# %% [markdown]
# # Chapter 10: Machine Learning Intro 2

# %%
# %reset
low_memory=False
import matplotlib.image as img
import matplotlib.pyplot as plt

import copy
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from os import listdir
from sklearn.model_selection import train_test_split
import seaborn as sns; sns.set()
from sklearn import metrics
from sklearn import preprocessing

# %% [markdown]
# ## 10.1 Introduction & Problem Setting
#
# If you have made it this far: great job, your almost at the end! The world of data processing holds no more secrets for you as you are no doubt an expert by now ;)
#
# To learn the new concepts you have seen today as well as circle back the the beginning of the course, let's think back to the first exercise you ever made. Today you will be working on a new, more specific case of fraud detection!
#
# You are processing a bunch of confidential and important documents. Each of these documents have to contain a signature. In order to help avoid issues, your boss is asking you if you can help her in identifying potential fraudulent signatures. Luckily she has provided you with a bunch of signatures from previous documents, as well as signatures that were fake.

# %% [markdown]
# ## 10.2 Data loading

# %% [markdown]
# Load in the images from the training set. You will not be able to load all the individual pixels in a dataframe (I mean you could, but it's not efficient). Think about the images and get creative with what kind of information might be important to retain so we can see if a signature is fake or not. Load in the dataset like so!
#
# *Hint: load in a single signature first and display it. Think about the distinguishing features. Are there colours? What about the size? Are the lines spread out? ...*

# %% [markdown]
# Next, build your outcome vector. Make use of the given csv file and ensure the information is linked to the correct image! Use 'forged' as the variable you wish to predict.

# %% [markdown]
# ## 10.3: Model Creation & Evaluation

# %% [markdown]
# Now train a model like we have seen before. Load in the test set in the same way as your dataset and evaluate your model!

# %% [markdown]
# ## 10.4 Putting your model in action

# %% [markdown]
# Consider the incoming document "bank_statement.pdf". Is this real or fake?

# %% [markdown]
# ## 10.5 Bonus (not required): Can you create a model to predict which ID the signature belongs to?
